# %%
import seaborn as sns
import pandas as pd

colors = sns.color_palette("viridis", n_colors=60)
colors_hex = sns.color_palette(colors).as_hex()
dates_month = pd.date_range(start='2020-01', end='2024-12', freq='MS') # Dates

year = 2020
print(f'\t{year}\n')
for i, color in enumerate(colors_hex):
    print(f"({i}) {dates_month[i].strftime('%Y-%m')}: {color}")
    if (i + 1) % 12 == 0 and year != 2024:
        year += 1
        print(f'\n\t{year}\n')
# Out:
# 	2020
#
# (0) 2020-01: #46075a
# (1) 2020-02: #470d60
# (2) 2020-03: #471365
# (3) 2020-04: #48186a
# (4) 2020-05: #481d6f
# (5) 2020-06: #482475
# (6) 2020-07: #482979
# (7) 2020-08: #472e7c
# (8) 2020-09: #46337f
# (9) 2020-10: #453882
# (10) 2020-11: #433e85
# (11) 2020-12: #414287
#
# 	2021
#
# (12) 2021-01: #3f4788
# (13) 2021-02: #3e4c8a
# (14) 2021-03: #3c508b
# (15) 2021-04: #39558c
# (16) 2021-05: #375a8c
# (17) 2021-06: #355e8d
# (18) 2021-07: #33628d
# (19) 2021-08: #31668e
# (20) 2021-09: #2f6b8e
# (21) 2021-10: #2e6f8e
# (22) 2021-11: #2c728e
# (23) 2021-12: #2a768e
#
# 	2022
#
# (24) 2022-01: #297a8e
# (25) 2022-02: #277f8e
# (26) 2022-03: #26828e
# (27) 2022-04: #24868e
# (28) 2022-05: #238a8d
# (29) 2022-06: #218e8d
# (30) 2022-07: #20928c
# (31) 2022-08: #1f968b
# (32) 2022-09: #1f9a8a
# (33) 2022-10: #1f9e89
# (34) 2022-11: #1fa187
# (35) 2022-12: #21a685
#
# 	2023
#
# (36) 2023-01: #24aa83
# (37) 2023-02: #27ad81
# (38) 2023-03: #2cb17e
# (39) 2023-04: #31b57b
# ...
